# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline
data=pd.read_csv(r'C:\Users\91946\Downloads\adult.data',sep=',')

# %%
data
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.dtypes
# Out:
# 39                 int64
#  State-gov        object
#  77516             int64
#  Bachelors        object
#  13                int64
#  Never-married    object
#  Adm-clerical     object
#  Not-in-family    object
#  White            object
#  Male             object
#  2174              int64
#  0                 int64
#  40                int64
#  United-States    object
#  <=50K            object
# dtype: object

# %%
data.describe().T
# Out:
#           count           mean            std      min       25%       50%  \
# 39      32560.0      38.581634      13.640642     17.0      28.0      37.0
#  77516  32560.0  189781.814373  105549.764924  12285.0  117831.5  178363.0
#  13     32560.0      10.080590       2.572709      1.0       9.0      10.0
#  2174   32560.0    1077.615172    7385.402999      0.0       0.0       0.0
#  0      32560.0      87.306511     402.966116      0.0       0.0       0.0
#  40     32560.0      40.437469      12.347618      1.0      40.0      40.0
#
#              75%        max
# 39          48.0       90.0
#  77516  237054.5  1484705.0
#  13         12.0       16.0
#  2174        0.0    99999.0
#  0           0.0     4356.0
#  40         45.0       99.0

# %%
data.describe(include="all").T
# Out:
#                   count unique                  top   freq           mean  \
# 39              32560.0    NaN                  NaN    NaN      38.581634
#  State-gov        32560      9              Private  22696            NaN
#  77516          32560.0    NaN                  NaN    NaN  189781.814373
#  Bachelors        32560     16              HS-grad  10501            NaN
#  13             32560.0    NaN                  NaN    NaN       10.08059
#  Never-married    32560      7   Married-civ-spouse  14976            NaN
#  Adm-clerical     32560     15       Prof-specialty   4140            NaN
#  Not-in-family    32560      6              Husband  13193            NaN
#  White            32560      5                White  27815            NaN
#  Male             32560      2                 Male  21789            NaN
#  2174           32560.0    NaN                  NaN    NaN    1077.615172
#  0              32560.0    NaN                  NaN    NaN      87.306511
# ...

# %%
data[data.duplicated()]
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 4880   25            Private  308144      Bachelors   13        Never-married
# 5103   90            Private   52386   Some-college   10        Never-married
# 9170   21            Private  250051   Some-college   10        Never-married
# 11630  20            Private  107658   Some-college   10        Never-married
# 13083  25            Private  195994        1st-4th    2        Never-married
# 15058  21            Private  243368      Preschool    1        Never-married
# 17039  46            Private  173243        HS-grad    9   Married-civ-spouse
# 18554  30            Private  144593        HS-grad    9        Never-married
# 18697  19            Private   97261        HS-grad    9        Never-married
# 21317  19            Private  138153   Some-college   10        Never-married
# 21489  19            Private  146679   Some-college   10        Never-married
# ...

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data_copy[data_copy.duplicated()]
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 4880   25            Private  308144      Bachelors   13        Never-married
# 5103   90            Private   52386   Some-college   10        Never-married
# 9170   21            Private  250051   Some-college   10        Never-married
# 11630  20            Private  107658   Some-college   10        Never-married
# 13083  25            Private  195994        1st-4th    2        Never-married
# 15058  21            Private  243368      Preschool    1        Never-married
# 17039  46            Private  173243        HS-grad    9   Married-civ-spouse
# 18554  30            Private  144593        HS-grad    9        Never-married
# 18697  19            Private   97261        HS-grad    9        Never-married
# 21317  19            Private  138153   Some-college   10        Never-married
# 21489  19            Private  146679   Some-college   10        Never-married
# ...

# %%
data_copy.sample(20)
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 197    35            Private  138992        Masters   14   Married-civ-spouse
# 15960  47          Local-gov  198660      Bachelors   13   Married-civ-spouse
# 590    55                  ?  105138        HS-grad    9   Married-civ-spouse
# 4818   56            Private  191917     Assoc-acdm   12             Divorced
# 22211  52          Local-gov   84808        HS-grad    9             Divorced
# 22876  26       Self-emp-inc  109240      Bachelors   13        Never-married
# 27872  42            Private  319016        HS-grad    9   Married-civ-spouse
# 8356   39          Local-gov  134367        HS-grad    9        Never-married
# 12846  21            Private  548303        HS-grad    9   Married-civ-spouse
# 23097  40            Private  219591           10th    6   Married-civ-spouse
# 28259  43            Private   54611        HS-grad    9   Married-civ-spouse
# ...

# %%
data_copy=data_copy.rename(columns={"39":"Age"})

data_copy
# Out:
#        Age          State-gov   77516    Bachelors   13        Never-married  \
# 0       50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1       38            Private  215646      HS-grad    9             Divorced
# 2       53            Private  234721         11th    7   Married-civ-spouse
# 3       28            Private  338409    Bachelors   13   Married-civ-spouse
# 4       37            Private  284582      Masters   14   Married-civ-spouse
# ...    ...                ...     ...          ...  ...                  ...
# 32555   27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556   40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557   58            Private  151910      HS-grad    9              Widowed
# 32558   22            Private  201490      HS-grad    9        Never-married
# 32559   52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
  data_copy_df=pd.DataFrame(data_copy)
  data_copy_df.columns
# Out:
# Index(['Age', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data_copy_df.rename(
    columns={' State-gov': 'Workclass', ' 40': "Hour_per_week", " Never-married": "Martial-Status",' 77516':'fnlwgt', ' Bachelors':'Education', ' 13':'Education_num',
             ' Adm-clerical':'Occupation', ' Not-in-family':'Relationship', ' White':'Race', ' Male':'Sex', ' 2174':'Capital_gain', ' 0':'Capital_loss', ' United-States':'Native-country', ' <=50K':'Income'},
    inplace=True,
)

data_copy_df.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Martial-Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hour_per_week  Native-country  Income
# 0             0             0             13   United-States   <=50K
# ...

# %%
data_copy_df['fnlwgt'].value_counts()
# Out:
# 203488    13
# 123011    13
# 164190    13
# 121124    12
# 148995    12
#           ..
# 218551     1
# 201204     1
# 362999     1
# 162297     1
# 145522     1
# Name: fnlwgt, Length: 21647, dtype: int64

# %%
data_copy_df.describe(include="all").T
# Out:
#                   count unique                  top   freq           mean  \
# Age             32560.0    NaN                  NaN    NaN      38.581634
# Workclass         32560      9              Private  22696            NaN
# fnlwgt          32560.0    NaN                  NaN    NaN  189781.814373
# Education         32560     16              HS-grad  10501            NaN
# Education_num   32560.0    NaN                  NaN    NaN       10.08059
# Martial-Status    32560      7   Married-civ-spouse  14976            NaN
# Occupation        32560     15       Prof-specialty   4140            NaN
# Relationship      32560      6              Husband  13193            NaN
# Race              32560      5                White  27815            NaN
# Sex               32560      2                 Male  21789            NaN
# Capital_gain    32560.0    NaN                  NaN    NaN    1077.615172
# Capital_loss    32560.0    NaN                  NaN    NaN      87.306511
# ...

# %%
data_copy_df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
data_copy_df['Native-country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
data_copy_df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
data_copy_df.nunique()
# Out:
# Age                  73
# Workclass             9
# fnlwgt            21647
# Education            16
# Education_num        16
# Martial-Status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hour_per_week        94
# Native-country       42
# Income                2
# dtype: int64

# %%
data_copy_df['Martial-Status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Martial-Status, dtype: int64

# %%
data_copy_df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
data_copy_df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
sns.countplot(data_copy_df['Income'],palette='Accent',data=data_copy_df);

# %%
data_copy_df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education_num     0
# Martial-Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hour_per_week     0
# Native-country    0
# Income            0
# dtype: int64

# %%
#df["column-name"] = df["column-name"].str.replace('abc', 'def')#replacing with most frequently occuring values
data_copy_df['Workclass']=data_copy_df['Workclass'].str.replace('?','Private')

data_copy_df['Native-country']=data_copy_df['Native-country'].str.replace('?','United-States')
data_copy_df['Occupation']=data_copy_df['Occupation'].str.replace('?','Prof-specialty')
data_copy_df
# Out:
#        Age          Workclass  fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Martial-Status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data_copy_df.sample(50)
# Out:
#        Age      Workclass  fnlwgt      Education  Education_num  \
# 32508   32        Private  192965        HS-grad              9
# 29345   48        Private  498328           10th              6
# 20239   36        Private  241998      Bachelors             13
# 19126   46        Private  164682      Assoc-voc             11
# 9978    47      Local-gov  287320        Masters             14
# 29009   47        Private  235986        HS-grad              9
# 26944   22        Private  123727   Some-college             10
# 47      41      State-gov  101603      Assoc-voc             11
# 6431    38        Private  104094   Some-college             10
# 8551    42        Private  213464   Some-college             10
# 2512    47        Private  174525        HS-grad              9
# 14886   58        Private  158506           11th              7
# 11333   59        Private  188070        Masters             14
# 22599   51        Private  207449      Bachelors             13
# ...

# %%
data_copy_df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
data_copy_df['Education']=data_copy_df['Education'].str.replace('7th-8th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('10th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('9th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('11th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('12th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('5th-6th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('1st-4th','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Preschool','School')
data_copy_df['Education']=data_copy_df['Education'].str.replace(' HS-grad',' High_School')
 
data_copy_df['Education']=data_copy_df['Education'].str.replace('Assoc-voc','Higher')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Assoc-acdm','Higher')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Prof-school','Higher')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Some-college','Higher')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Bachelors','Undergraduate')
data_copy_df['Education']=data_copy_df['Education'].str.replace('Masters',' Graduate')

# %%
data_copy_df
# Out:
#        Age          Workclass  fnlwgt       Education  Education_num  \
# 0       50   Self-emp-not-inc   83311   Undergraduate             13
# 1       38            Private  215646     High_School              9
# 2       53            Private  234721          School              7
# 3       28            Private  338409   Undergraduate             13
# 4       37            Private  284582        Graduate             14
# ...    ...                ...     ...             ...            ...
# 32555   27            Private  257302          Higher             12
# 32556   40            Private  154374     High_School              9
# 32557   58            Private  151910     High_School              9
# 32558   22            Private  201490     High_School              9
# 32559   52       Self-emp-inc  287927     High_School              9
#
#             Martial-Status          Occupation    Relationship    Race  \
# ...

# %%
data_copy_df.sample(50)
# Out:
#        Age          Workclass  fnlwgt       Education  Education_num  \
# 12397   43          Local-gov  241528        Graduate             14
# 27350   46            Private  157991          Higher             11
# 422     29            Private  188401     High_School              9
# 17262   34            Private  176992          Higher             10
# 22956   17            Private   54257          School              7
# 13852   24            Private  200295          Higher             10
# 22431   50   Self-emp-not-inc  172281     High_School              9
# 12338   20          Local-gov  271354     High_School              9
# 30449   39            Private   86551          School              8
# 4549    38   Self-emp-not-inc  108947          Higher             10
# 27043   32            Private  164197   Undergraduate             13
# 17942   36        Federal-gov  192150     High_School              9
# 17246   19            Private   32477          Higher             10
# ...

# %%
data_copy_df['Martial-Status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Martial-Status, dtype: int64

# %%
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Married-civ-spouse','Married')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Married-AF-spouse','Married')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Never-married','UnMarried')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Divorced','Others')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Separated','Others')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Widowed','Others')
data_copy_df['Martial-Status']=data_copy_df['Martial-Status'].str.replace('Married-spouse-absent','Others')

# %%
data_copy_df
# Out:
#        Age          Workclass  fnlwgt       Education  Education_num  \
# 0       50   Self-emp-not-inc   83311   Undergraduate             13
# 1       38            Private  215646     High_School              9
# 2       53            Private  234721          School              7
# 3       28            Private  338409   Undergraduate             13
# 4       37            Private  284582        Graduate             14
# ...    ...                ...     ...             ...            ...
# 32555   27            Private  257302          Higher             12
# 32556   40            Private  154374     High_School              9
# 32557   58            Private  151910     High_School              9
# 32558   22            Private  201490     High_School              9
# 32559   52       Self-emp-inc  287927     High_School              9
#
#       Martial-Status          Occupation    Relationship    Race      Sex  \
# ...

# %%
data_copy_df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
data_copy_df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
#data_copy_df['Income'].astype(int)
data_copy_df['Income']=data_copy_df['Income'].str.replace('<=50K','0')
data_copy_df['Income']=data_copy_df['Income'].str.replace('>50K','1')
data_copy_df["Income"] = pd.to_numeric(data_copy_df["Income"])
#df['Education'].replace(['Under-Graduate', 'Diploma '],
                    #    [0, 1], inplace=True)

# %%
data_copy_df
# Out:
#        Age          Workclass  fnlwgt       Education  Education_num  \
# 0       50   Self-emp-not-inc   83311   Undergraduate             13
# 1       38            Private  215646     High_School              9
# 2       53            Private  234721          School              7
# 3       28            Private  338409   Undergraduate             13
# 4       37            Private  284582        Graduate             14
# ...    ...                ...     ...             ...            ...
# 32555   27            Private  257302          Higher             12
# 32556   40            Private  154374     High_School              9
# 32557   58            Private  151910     High_School              9
# 32558   22            Private  201490     High_School              9
# 32559   52       Self-emp-inc  287927     High_School              9
#
#       Martial-Status          Occupation    Relationship    Race      Sex  \
# ...

# %%
#data_copy_df['Income'].astype(int)

# %%
numeric_features = [feature for feature in data_copy_df.columns if data_copy_df[feature].dtype != 'O']

# %%
numeric_features
# Out:
# ['Age',
#  'fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hour_per_week',
#  'Income']

# %%
data_copy_df[numeric_features]
# Out:
#        Age  fnlwgt  Education_num  Capital_gain  Capital_loss  Hour_per_week  \
# 0       50   83311             13             0             0             13
# 1       38  215646              9             0             0             40
# 2       53  234721              7             0             0             40
# 3       28  338409             13             0             0             40
# 4       37  284582             14             0             0             40
# ...    ...     ...            ...           ...           ...            ...
# 32555   27  257302             12             0             0             38
# 32556   40  154374              9             0             0             40
# 32557   58  151910              9             0             0             40
# 32558   22  201490              9             0             0             20
# 32559   52  287927              9         15024             0             40
#
#        Income
# 0           0
# ...

# %%
categorical_features = [feature for feature in data_copy_df.columns if data_copy_df[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['Workclass',
#  'Education',
#  'Martial-Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native-country']

# %%
data_copy_df[categorical_features]
# Out:
#                Workclass       Education Martial-Status          Occupation  \
# 0       Self-emp-not-inc   Undergraduate        Married     Exec-managerial
# 1                Private     High_School         Others   Handlers-cleaners
# 2                Private          School        Married   Handlers-cleaners
# 3                Private   Undergraduate        Married      Prof-specialty
# 4                Private        Graduate        Married     Exec-managerial
# ...                  ...             ...            ...                 ...
# 32555            Private          Higher        Married        Tech-support
# 32556            Private     High_School        Married   Machine-op-inspct
# 32557            Private     High_School         Others        Adm-clerical
# 32558            Private     High_School      UnMarried        Adm-clerical
# 32559       Self-emp-inc     High_School        Married     Exec-managerial
#
#          Relationship    Race      Sex  Native-country
# ...

# %%
for col in categorical_features:
    print(f"{col}:{data_copy_df[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# Workclass: Private             75.343980
#  Self-emp-not-inc     7.804054
#  Local-gov            6.428133
#  State-gov            3.983415
#  Self-emp-inc         3.427518
#  Federal-gov          2.948403
#  Without-pay          0.042998
#  Never-worked         0.021499
# Name: Workclass, dtype: float64
# ...
# Education: High_School      32.251229
#  Higher           31.683047
#  Undergraduate    16.443489
#  School           13.062039
#   Graduate         5.291769
#  Doctorate         1.268428
# Name: Education, dtype: float64
# ...
# Martial-Status: Married      46.065725
#  UnMarried    32.807125
#  Others       21.127150
# Name: Martial-Status, dtype: float64
# ...
# Occupation: Prof-specialty       18.375307
#  Craft-repair         12.589066
#  Exec-managerial      12.487715
#  Adm-clerical         11.575553
#  Sales                11.210074
#  Other-service        10.119779
#  Machine-op-inspct     6.148649
#  Transport-moving      4.904791
#  Handlers-cleaners     4.207617
# ...

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=data_copy_df["Workclass"]);

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Workclass', 'Education']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=data_copy_df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Age',
#  'fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hour_per_week',
#  'Income']

# %%
sns.kdeplot(data_copy_df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data_copy_df['Hour_per_week'])
# Out:
# <AxesSubplot:xlabel='Hour_per_week', ylabel='Density'>

# %%
plt.hist(data_copy_df["Hour_per_week"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data_copy_df[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
data_copy_df["Workclass"].value_counts().plot.pie(y=data_copy_df["Workclass"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Workclass'>

# %%
data_copy_df_work=data_copy_df["Workclass"].value_counts()[:8]
workclass = pd.DataFrame(data_copy_df['Workclass'].value_counts())        #Dataframe of apps on the basis of workclass
workclass.rename(columns = {'Workclass':'Count'},inplace=True)

plt.figure(figsize=(15,6))
sns.barplot(x=data_copy_df_work, y ='Count',data = workclass[:8],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
#which gender is more in workclass)
type(data_copy_df.groupby(['Workclass'])['Hour_per_week'].sum().sort_values(ascending=False))
# Out:
# pandas.core.series.Series

# %%
df_workclass_sex=data_copy_df.groupby(['Workclass'])['Hour_per_week'].sum().sort_values(ascending=False).reset_index()
df2=df_workclass_sex.head(10)
df2
# Out:
#            Workclass  Hour_per_week
# 0            Private         972506
# 1   Self-emp-not-inc         112876
# 2          Local-gov          85777
# 3       Self-emp-inc          54481
# 4          State-gov          50623
# 5        Federal-gov          39724
# 6        Without-pay            458
# 7       Never-worked            199

# %%
sns.barplot(x="Hour_per_week",y="Workclass",data=df2)
# Out:
# <AxesSubplot:xlabel='Hour_per_week', ylabel='Workclass'>

# %%
plt.figure(figsize = (10,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Hour_per_week' , y = 'Workclass' , data = df2 )
ax.set_xlabel('No. of hour_per_week')
ax.set_ylabel('')
ax.set_title("workclass having highest Hour_per_week", size = 20)
# Out:
# Text(0.5, 1.0, 'workclass having highest Hour_per_week')

# %%
data_copy_df
# Out:
#        Age          Workclass  fnlwgt       Education  Education_num  \
# 0       50   Self-emp-not-inc   83311   Undergraduate             13
# 1       38            Private  215646     High_School              9
# 2       53            Private  234721          School              7
# 3       28            Private  338409   Undergraduate             13
# 4       37            Private  284582        Graduate             14
# ...    ...                ...     ...             ...            ...
# 32555   27            Private  257302          Higher             12
# 32556   40            Private  154374     High_School              9
# 32557   58            Private  151910     High_School              9
# 32558   22            Private  201490     High_School              9
# 32559   52       Self-emp-inc  287927     High_School              9
#
#       Martial-Status          Occupation    Relationship    Race      Sex  \
# ...

# %%
#which top 5 workclass occupation hashighest hours_per_week

# %%
data_copy_df.head()
# Out:
#    Age          Workclass  fnlwgt       Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Undergraduate             13
# 1   38            Private  215646     High_School              9
# 2   53            Private  234721          School              7
# 3   28            Private  338409   Undergraduate             13
# 4   37            Private  284582        Graduate             14
#
#   Martial-Status          Occupation    Relationship    Race      Sex  \
# 0        Married     Exec-managerial         Husband   White     Male
# 1         Others   Handlers-cleaners   Not-in-family   White     Male
# 2        Married   Handlers-cleaners         Husband   Black     Male
# 3        Married      Prof-specialty            Wife   Black   Female
# 4        Married     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hour_per_week  Native-country  Income
# 0             0             0             13   United-States       0
# ...

# %%
dfa1=data_copy_df.groupby(['Workclass','Occupation'])['Hour_per_week'].sum().sort_values(ascending=False).reset_index()

# %%
dfa1.head()
# Out:
#   Workclass        Occupation  Hour_per_week
# 0   Private    Prof-specialty         156288
# 1   Private      Craft-repair         135165
# 2   Private   Exec-managerial         120706
# 3   Private             Sales         115913
# 4   Private      Adm-clerical         106645

# %%
#dfa=dfa.sort_values('Hour_per_week',ascending=False)
dfa1
# Out:
#        Workclass          Occupation  Hour_per_week
# 0        Private      Prof-specialty         156288
# 1        Private        Craft-repair         135165
# 2        Private     Exec-managerial         120706
# 3        Private               Sales         115913
# 4        Private        Adm-clerical         106645
# ..           ...                 ...            ...
# 77   Without-pay       Other-service             55
# 78   Without-pay        Craft-repair             40
# 79   Without-pay   Handlers-cleaners             40
# 80   Without-pay   Machine-op-inspct             25
# 81   Without-pay    Transport-moving             20
#
# [82 rows x 3 columns]

# %%
dfa1=data_copy_df.groupby(['Workclass'])['Hour_per_week'].sum().sort_values(ascending=False).reset_index()
dfa1.head()
data_copy_df['Workclass'].value_counts()
# Out:
#  Private             24532
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
data_copy_df['Occupation'].value_counts()
# Out:
#  Prof-specialty       5983
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
numeric_features
# Out:
# ['Age',
#  'fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hour_per_week',
#  'Income']

# %%
#histogram
data_copy_df.hist(figsize=(15,15),layout=(3,3))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'fnlwgt'}>,
#         <AxesSubplot:title={'center':'Education_num'}>],
#        [<AxesSubplot:title={'center':'Capital_gain'}>,
#         <AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hour_per_week'}>],
#        [<AxesSubplot:title={'center':'Income'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#box plot

# %%
data_copy_df.plot(kind='box',figsize=(12,12),layout=(3,3),sharex=False,subplots=True);

# %%
plt.figure(figsize=(15,4))
sns.countplot(data_copy_df['Race'],hue='Income',data=data_copy_df,palette='magma');

# %%
plt.figure(figsize=(15,5))
sns.countplot(data_copy_df['Education'],hue='Income',data=data_copy_df,palette='magma');

# %%
plt.figure(figsize=(25,5))
sns.countplot(data_copy_df['Education'],hue='Sex',data=data_copy_df,palette='magma');

# %%
data_copy_df["Income"].value_counts().plot.pie(y=data_copy_df["Income"],figsize=(15,15),autopct='%1.1f%%');

# %%
pie plot showing only 24.1% are having  income above >50k
